# %% [markdown]
# # 03 — Model Training
#
# Train MobileNet triage model on processed/augmented data; save checkpoints and metrics.

# %%
# Add training code here
import sys
sys.path.insert(0, '..')
# from src.models.mobilenet_triage import build_model, train_model
