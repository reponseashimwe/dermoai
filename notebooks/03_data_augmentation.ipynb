# %% [markdown]
# # 03: Data Augmentation & Train/Val/Test Split
#
# ## Objective
# This notebook performs:
# 1. **Label Mapping** from raw conditions to FINAL model classes (5 FST V-VI optimised classes)
# 2. **Stratified Train/Val/Test Split** (60/20/20) preserving both final class and FST (V vs VI) distributions
# 3. **Targeted Augmentation** to reach 250 images per class for training viability
# 4. **Quality Validation** to ensure clinical realism and no data leakage
#
# ## Context
# - Total images: 2,155 (FST V–VI from Fitzpatrick17k)
# - Original conditions: 112 dermatological diagnoses
# - **Final model classes: 5** (FST V-VI optimised, clinically viable conditions)
# - Augmentation purpose: **Viability — reach minimum threshold per class**
# - Conditions not matching any named class are EXCLUDED from training
# - At inference time: low confidence predictions → REFER (confidence threshold)
#
# ## Final Classes (Model Output Space)
# **5 FST V-VI Optimised Classes:**
# 1. **pityriasis_rubra_pilaris** — Higher prevalence in African populations (see split output for verified counts)
# 2. **lupus_erythematosus** — More severe discoid scarring in FST V-VI (see split output for verified counts)
# 3. **psoriasis** — Frequently misdiagnosed in dark skin due to colour masking (see split output for verified counts)
# 4. **neurofibromatosis** — Genodermatosis with distinct cutaneous manifestations (see split output for verified counts)
# 5. **scabies** — Hyperendemic in Rwanda; harder to detect in FST V-VI (see split output for verified counts)
#
# ## Class Selection Rationale
# Classes were selected based on two criteria:
# - Sufficient training images after 60/20/20 split (minimum ~40 in train set — statistical viability for transfer learning)
# - Documented relevance to FST V-VI populations or Sub-Saharan Africa disease burden
#
# **Classes considered but excluded:**
# - **lichen_planus** (81 total images): Removed due to documented diagnostic ambiguity. Inter-observer disagreement in diagnosing lichen planus is well-recognised in dermatology literature, particularly on FST V-VI skin where post-inflammatory hyperpigmentation obscures classical features. Empirically confirmed during training — its inclusion consistently degraded recall across all other classes.
# - **squamous_cell_carcinoma** (44 total images): Insufficient training samples for a malignancy; misclassification risk unacceptable.
# - **vitiligo** (42 total images): Insufficient training samples for reliable feature learning.
#
# ## Triage Mapping (Stage 2 — Rule Based)
# - **REFER**: pityriasis_rubra_pilaris, lupus_erythematosus, UNCERTAIN (low confidence)
# - **MANAGE LOCALLY**: neurofibromatosis, psoriasis, scabies

# %%
# Import required libraries
import os
import json
import shutil
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.model_selection import train_test_split
from collections import Counter
import albumentations as A
from tqdm.auto import tqdm
import warnings

warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print(f"Random seed set to: {RANDOM_SEED}")
print("Libraries imported successfully!")
# Out:
# Random seed set to: 42
# Libraries imported successfully!

# %% [markdown]
# ## 1. Configuration & Paths

# %%
# Define paths
BASE_DIR = Path('../')
DATA_RAW_DIR = BASE_DIR / 'data' / 'raw' / 'fitzpatrick17k'
IMAGES_DIR = DATA_RAW_DIR / 'images'
METADATA_FILE = DATA_RAW_DIR / 'fitzpatrick17k_fst_v_vi.csv'

# Output directories
OUTPUT_DIR = BASE_DIR / 'data' / 'processed' / 'fitzpatrick17k'
TRAIN_DIR = OUTPUT_DIR / 'train'
VAL_DIR = OUTPUT_DIR / 'val'
TEST_DIR = OUTPUT_DIR / 'test'

# Augmented training set
AUGMENTED_DIR = BASE_DIR / 'data' / 'augmented' / 'train'

# Split ratios — 60/20/20
# 448 total images across 5 classes (~90/class)
# 60/20/20 gives ~54 train, ~18 val, ~18 test per class
# Augmentation brings train to 250/class
TRAIN_RATIO = 0.60
VAL_RATIO = 0.20
TEST_RATIO = 0.20

TARGET_SIZE = (224, 224)

# Clear existing splits to avoid mixing old and new data
import shutil
for dir_path in [OUTPUT_DIR, AUGMENTED_DIR]:
    if dir_path.exists():
        shutil.rmtree(dir_path)
        print(f"Cleared: {dir_path}")

for dir_path in [OUTPUT_DIR, TRAIN_DIR, VAL_DIR, TEST_DIR, AUGMENTED_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

print("Paths configured:")
print(f"  Metadata:  {METADATA_FILE}")
print(f"  Images:    {IMAGES_DIR}")
print(f"  Output:    {OUTPUT_DIR}")
print(f"  Augmented: {AUGMENTED_DIR}")
print(f"\nSplit ratios: {TRAIN_RATIO}/{VAL_RATIO}/{TEST_RATIO}")
print(f"Expected per class — Train: ~{int(90*TRAIN_RATIO)} | Val: ~{int(90*VAL_RATIO)} | Test: ~{int(90*TEST_RATIO)}")
print(f"After augmentation — Train: 250 per class")
# Out:
# Cleared: ../data/processed/fitzpatrick17k
# Cleared: ../data/augmented/train
# Paths configured:
#   Metadata:  ../data/raw/fitzpatrick17k/fitzpatrick17k_fst_v_vi.csv
#   Images:    ../data/raw/fitzpatrick17k/images
#   Output:    ../data/processed/fitzpatrick17k
#   Augmented: ../data/augmented/train
#
# Split ratios: 0.6/0.2/0.2
# Expected per class — Train: ~54 | Val: ~18 | Test: ~18
# After augmentation — Train: 250 per class

# %% [markdown]
# ## 2. Load Data & Verify Image Existence

# %%
# Load metadata
df = pd.read_csv(METADATA_FILE)
print(f"Loaded {len(df)} records from metadata")
print(f"Columns: {list(df.columns)}")
print(f"\nFirst 3 rows:")
print(df.head(3))

# Verify image existence
df['image_path'] = df['md5hash'].apply(lambda x: IMAGES_DIR / f"{x}.jpg")
df['image_exists'] = df['image_path'].apply(lambda x: x.exists())

missing_count = (~df['image_exists']).sum()
print(f"\nImage verification:")
print(f"  Total records: {len(df)}")
print(f"  Images found: {df['image_exists'].sum()}")
print(f"  Images missing: {missing_count}")

# Remove missing images
if missing_count > 0:
    print(f"\nRemoving {missing_count} records with missing images...")
    df = df[df['image_exists']].copy()
    print(f"Remaining records: {len(df)}")

print(f"\nFitzpatrick Skin Type distribution:")
print(df['fitzpatrick_scale'].value_counts().sort_index())
# Out:
# Loaded 2155 records from metadata
# Columns: ['md5hash', 'fitzpatrick_scale', 'fitzpatrick_centaur', 'label', 'nine_partition_label', 'three_partition_label', 'qc', 'url', 'url_alphanum']
#
# First 3 rows:
#                             md5hash  fitzpatrick_scale  fitzpatrick_centaur  \
# 0  45f7fe0e10214e32e890cad9d29d4811                  6                    5
# 1  ddcad677b7b1e9084f3f51a8e026aa8d                  5                    5
# 2  1e119546f5bc2b9165bb10ddd7fe5f69                  5                    4
#
#                    label nine_partition_label three_partition_label   qc  \
# 0         kaposi sarcoma     malignant dermal             malignant  NaN
# 1           hidradenitis         inflammatory        non-neoplastic  NaN
# 2  xeroderma pigmentosum       genodermatoses        non-neoplastic  NaN
#
#                                                  url  \
# 0  https://www.dermaamin.com/site/images/clinical...
# 1  https://www.dermaamin.com/site/images/clinical...
# ...

# %% [markdown]
# ## 3. Label Mapping: Raw Conditions → Final Classes
#
# **5 FST V-VI OPTIMISED CLASSES**
#
# Only 5 conditions from the original 112 are retained as named classes.
# All other conditions are excluded from training — they will be handled
# at inference time by the confidence threshold mechanism (low confidence → REFER).
#
# **Selection criteria:**
# - Minimum ~40 training images after split (statistical viability for transfer learning)
# - Documented relevance to FST V-VI populations or SSA disease burden
#
# **5 Final Classes (total image counts):**
# 1. **pityriasis_rubra_pilaris** — 127 total images
# 2. **lupus_erythematosus** — 89 total images
# 3. **psoriasis** — 85 total images
# 4. **neurofibromatosis** — 74 total images
# 5. **scabies** — 73 total images
#
# **Excluded classes:**
# - **lichen_planus** (81 images): Diagnostic ambiguity documented in dermatology literature; inter-observer disagreement is particularly pronounced on FST V-VI skin. Confirmed empirically — inclusion degraded recall across all other classes during training iterations.
# - **squamous_cell_carcinoma** (44 images): Insufficient images; misclassification risk unacceptable for a malignancy.
# - **vitiligo** (42 images): Insufficient images for reliable feature learning.

# %%
# 5 FST V-VI optimised classes — final selection after iterative training
# 
# Dropped from consideration:
#   - lichen_planus (81 images): diagnostic ambiguity well-documented in literature;
#     inter-observer disagreement on FST V-VI confirmed empirically — degraded all class recall
#   - squamous_cell_carcinoma (44 images): too few images; misclassification risk
#     unacceptable for a malignancy
#   - vitiligo (42 images): too few images for reliable feature learning
#
# Retained 5 classes: 448 total images, ~90 average per class

NAMED_CONDITIONS = {
    'pityriasis rubra pilaris': 'pityriasis_rubra_pilaris',
    'neurofibromatosis':        'neurofibromatosis',
    'lupus erythematosus':      'lupus_erythematosus',
    'psoriasis':                'psoriasis',
    'scabies':                  'scabies',
}

# Apply mapping
df['final_class'] = df['label'].apply(
    lambda x: NAMED_CONDITIONS.get(x, None)
)

total_before = len(df)
excluded_count = df['final_class'].isna().sum()
retained_count = df['final_class'].notna().sum()

print(f"Total FST V-VI images:      {total_before}")
print(f"Retained (5 named classes): {retained_count}")
print(f"Excluded (112 other conditions + dropped lichen_planus/SCC/vitiligo): {excluded_count}")

df = df[df['final_class'].notna()].copy()
df = df.reset_index(drop=True)

print(f"\nFinal Class Distribution:")
final_dist = df['final_class'].value_counts().sort_values(ascending=False)
for cls, count in final_dist.items():
    pct = count / len(df) * 100
    print(f"  {cls:<35}: {count:>4} ({pct:>5.1f}%)")

# Triage mapping — REFER / MANAGE LOCALLY (replaces earlier Urgent/Non-Urgent terminology)
# REFER:         conditions requiring specialist review
# MANAGE LOCALLY: conditions manageable at health-centre level with guidance
# UNCERTAIN:     any prediction below confidence threshold → REFER as safety net
TRIAGE_MAPPING = {
    'pityriasis_rubra_pilaris': 'REFER',
    'neurofibromatosis':        'MANAGE LOCALLY',
    'lupus_erythematosus':      'REFER',
    'psoriasis':                'MANAGE LOCALLY',
    'scabies':                  'MANAGE LOCALLY',
    'UNCERTAIN':                'REFER',
}

print(f"\nTriage Mapping (5 classes):")
for cls, triage in TRIAGE_MAPPING.items():
    marker = '→ REFER' if triage == 'REFER' else '→ MANAGE LOCALLY'
    print(f"  {cls:<35} {marker}")

print(f"\nNote: All conditions excluded from named classes are handled at inference time.")
print(f"      Low confidence predictions → UNCERTAIN → REFER as safety net.")
# Out:
# Total FST V-VI images:      2155
# Retained (5 named classes): 448
# Excluded (112 other conditions + dropped lichen_planus/SCC/vitiligo): 1707
#
# Final Class Distribution:
#   pityriasis_rubra_pilaris           :  127 ( 28.3%)
#   lupus_erythematosus                :   89 ( 19.9%)
#   psoriasis                          :   85 ( 19.0%)
#   neurofibromatosis                  :   74 ( 16.5%)
#   scabies                            :   73 ( 16.3%)
#
# Triage Mapping (5 classes):
#   pityriasis_rubra_pilaris            → REFER
#   neurofibromatosis                   → MANAGE LOCALLY
#   lupus_erythematosus                 → REFER
#   psoriasis                           → MANAGE LOCALLY
#   scabies                             → MANAGE LOCALLY
#   UNCERTAIN                           → REFER
#
# Note: All conditions excluded from named classes are handled at inference time.
#       Low confidence predictions → UNCERTAIN → REFER as safety net.

# %% [markdown]
# ## 4. Prepare Stratification Labels
#
# We stratify by BOTH:
# - Final class label
# - Fitzpatrick Skin Type (V vs VI)
#
# This ensures both class and skin type distributions are preserved across splits.

# %%
# Create FST binary label (V vs VI)
df['fst_label'] = df['fitzpatrick_scale'].apply(
    lambda x: 'V' if x == 5 else 'VI'
)

# Create combined stratification label
df['stratify_label'] = df['final_class'] + '_' + df['fst_label']

print("Stratification labels created")
print(f"\nSample stratification labels:")
print(df[['final_class', 'fst_label', 'stratify_label']].head(10))

# Check stratification group sizes
strat_counts = df['stratify_label'].value_counts().sort_values()
print(f"\nStratification group sizes (smallest to largest):")
print(strat_counts.head(10))

min_group_size = strat_counts.min()
print(f"\nSmallest stratification group: {min_group_size} samples")
print(f"Test split requires ≥2 samples per group (with 15% split)")

if min_group_size < 2:
    print("\n⚠️ Some groups are too small for stratification")
    print("Groups with <2 samples:")
    print(strat_counts[strat_counts < 2])
# Out:
# Stratification labels created
#
# Sample stratification labels:
#                 final_class fst_label               stratify_label
# 0         neurofibromatosis        VI         neurofibromatosis_VI
# 1  pityriasis_rubra_pilaris         V   pityriasis_rubra_pilaris_V
# 2       lupus_erythematosus        VI       lupus_erythematosus_VI
# 3                 psoriasis         V                  psoriasis_V
# 4                 psoriasis         V                  psoriasis_V
# 5                 psoriasis        VI                 psoriasis_VI
# 6                 psoriasis         V                  psoriasis_V
# 7       lupus_erythematosus         V        lupus_erythematosus_V
# 8  pityriasis_rubra_pilaris         V   pityriasis_rubra_pilaris_V
# 9  pityriasis_rubra_pilaris        VI  pityriasis_rubra_pilaris_VI
#
# Stratification group sizes (smallest to largest):
# stratify_label
# neurofibromatosis_VI            12
# scabies_VI                      18
# ...

# %% [markdown]
# ## 5. Train/Val/Test Split (60/20/20)
#
# Stratified split preserving:
# - Final class distribution
# - FST V vs VI distribution
# - No data leakage between splits

# %%
def safe_stratified_split(df, stratify_col, test_size, random_state=42):
    """
    Perform stratified split, handling groups with insufficient samples.
    Groups with only 1 sample are randomly assigned.
    """
    # Identify groups with sufficient samples for stratification
    group_counts = df[stratify_col].value_counts()
    min_samples_needed = 2  # Minimum for any split
    
    sufficient_groups = group_counts[group_counts >= min_samples_needed].index
    insufficient_groups = group_counts[group_counts < min_samples_needed].index
    
    # Split sufficient groups with stratification
    df_sufficient = df[df[stratify_col].isin(sufficient_groups)]
    df_insufficient = df[df[stratify_col].isin(insufficient_groups)]
    
    if len(df_sufficient) > 0:
        train_val, test = train_test_split(
            df_sufficient,
            test_size=test_size,
            stratify=df_sufficient[stratify_col],
            random_state=random_state
        )
    else:
        train_val = pd.DataFrame()
        test = pd.DataFrame()
    
    # For insufficient groups, randomly assign
    if len(df_insufficient) > 0:
        train_val_insuf, test_insuf = train_test_split(
            df_insufficient,
            test_size=test_size,
            random_state=random_state
        )
        train_val = pd.concat([train_val, train_val_insuf])
        test = pd.concat([test, test_insuf])
    
    return train_val, test

# First split: train+val vs test
print("Splitting data: train+val vs test...")
train_val_df, test_df = safe_stratified_split(
    df,
    'stratify_label',
    test_size=TEST_RATIO,
    random_state=RANDOM_SEED
)

# Second split: train vs val
print("Splitting train+val: train vs val...")
val_ratio_adjusted = VAL_RATIO / (TRAIN_RATIO + VAL_RATIO)
train_df, val_df = safe_stratified_split(
    train_val_df,
    'stratify_label',
    test_size=val_ratio_adjusted,
    random_state=RANDOM_SEED
)

print(f"\n=== Split Summary ===")
print(f"Train: {len(train_df)} samples ({len(train_df)/len(df)*100:.1f}%)")
print(f"Val:   {len(val_df)} samples ({len(val_df)/len(df)*100:.1f}%)")
print(f"Test:  {len(test_df)} samples ({len(test_df)/len(df)*100:.1f}%)")
print(f"Total: {len(df)} samples")

# Verify no overlap
train_hashes = set(train_df['md5hash'])
val_hashes = set(val_df['md5hash'])
test_hashes = set(test_df['md5hash'])

assert len(train_hashes & val_hashes) == 0, "Data leakage: train-val overlap!"
assert len(train_hashes & test_hashes) == 0, "Data leakage: train-test overlap!"
assert len(val_hashes & test_hashes) == 0, "Data leakage: val-test overlap!"
print("\n✓ No data leakage detected")
# Out:
# Splitting data: train+val vs test...
# Splitting train+val: train vs val...
#
# === Split Summary ===
# Train: 268 samples (59.8%)
# Val:   90 samples (20.1%)
# Test:  90 samples (20.1%)
# Total: 448 samples
#
# ✓ No data leakage detected

# %% [markdown]
# ## 6. Verify Split Quality
#
# Check that final class and FST distributions are preserved.

# %%
def print_split_statistics(split_df, split_name):
    print(f"\n{'='*60}")
    print(f"{split_name.upper()} SET STATISTICS")
    print(f"{'='*60}")
    
    # Final class distribution
    print(f"\nFinal Class Distribution:")
    class_dist = split_df['final_class'].value_counts().sort_values(ascending=False)
    for cls, count in class_dist.items():
        pct = count / len(split_df) * 100
        print(f"  {cls:35s}: {count:4d} ({pct:5.1f}%)")
    
    # FST distribution
    print(f"\nFitzpatrick Skin Type Distribution:")
    fst_dist = split_df['fst_label'].value_counts().sort_index()
    for fst, count in fst_dist.items():
        pct = count / len(split_df) * 100
        print(f"  FST {fst}: {count:4d} ({pct:5.1f}%)")

# Print statistics for each split
print_split_statistics(train_df, "TRAIN")
print_split_statistics(val_df, "VALIDATION")
print_split_statistics(test_df, "TEST")

# Compare distributions across splits
print(f"\n{'='*60}")
print("DISTRIBUTION COMPARISON")
print(f"{'='*60}")

comparison_df = pd.DataFrame({
    'Train': train_df['final_class'].value_counts(normalize=True) * 100,
    'Val': val_df['final_class'].value_counts(normalize=True) * 100,
    'Test': test_df['final_class'].value_counts(normalize=True) * 100
}).fillna(0).round(1)

print("\nFinal Class Distribution (%) across splits:")
print(comparison_df)
# Out:
# ...
# TRAIN SET STATISTICS
# ...
#
# Final Class Distribution:
#   pityriasis_rubra_pilaris           :   76 ( 28.4%)
#   lupus_erythematosus                :   53 ( 19.8%)
#   psoriasis                          :   51 ( 19.0%)
#   neurofibromatosis                  :   45 ( 16.8%)
#   scabies                            :   43 ( 16.0%)
#
# Fitzpatrick Skin Type Distribution:
#   FST V:  201 ( 75.0%)
#   FST VI:   67 ( 25.0%)
#
# ...
# VALIDATION SET STATISTICS
# ...
#
# Final Class Distribution:
#   pityriasis_rubra_pilaris           :   26 ( 28.9%)
#   lupus_erythematosus                :   18 ( 20.0%)
#   psoriasis                          :   17 ( 18.9%)
#   scabies                            :   15 ( 16.7%)
#   neurofibromatosis                  :   14 ( 15.6%)
#
# Fitzpatrick Skin Type Distribution:
#   FST V:   67 ( 74.4%)
#   FST VI:   23 ( 25.6%)
#
# ...
# TEST SET STATISTICS
# ...
#
# Final Class Distribution:
#   pityriasis_rubra_pilaris           :   25 ( 27.8%)
# ...

# %% [markdown]
# ## 7. Copy and Preprocess Images to Split Directories
#
# All images are:
# - Converted to RGB
# - Resized to 224×224
# - Saved as JPEG
# - Organized in ImageFolder-compatible structure: `split/class/image.jpg`

# %%
def copy_images_to_split(split_df, split_dir, split_name):
    """
    Copy and preprocess images to split directory.
    Structure: split_dir / final_class / image.jpg
    """
    print(f"\nProcessing {split_name} split...")
    
    # Create class directories
    classes = split_df['final_class'].unique()
    for cls in classes:
        class_dir = split_dir / cls
        class_dir.mkdir(parents=True, exist_ok=True)
    
    # Copy and preprocess images
    copied_count = 0
    error_count = 0
    
    for idx, row in tqdm(split_df.iterrows(), total=len(split_df), desc=f"Copying {split_name}"):
        try:
            # Load image
            img = Image.open(row['image_path'])
            
            # Convert to RGB (handle RGBA, grayscale, etc.)
            if img.mode != 'RGB':
                img = img.convert('RGB')
            
            # Resize to 224×224
            img = img.resize(TARGET_SIZE, Image.Resampling.LANCZOS)
            
            # Save to class directory
            dest_path = split_dir / row['final_class'] / f"{row['md5hash']}.jpg"
            img.save(dest_path, 'JPEG', quality=95)
            
            copied_count += 1
            
        except Exception as e:
            print(f"Error processing {row['md5hash']}: {e}")
            error_count += 1
    
    print(f"\n{split_name} Summary:")
    print(f"  Successfully copied: {copied_count}")
    print(f"  Errors: {error_count}")
    print(f"  Classes: {len(classes)}")
    
    return copied_count

# Process all splits
train_copied = copy_images_to_split(train_df, TRAIN_DIR, "TRAIN")
val_copied = copy_images_to_split(val_df, VAL_DIR, "VAL")
test_copied = copy_images_to_split(test_df, TEST_DIR, "TEST")

print(f"\n{'='*60}")
print(f"Total images copied: {train_copied + val_copied + test_copied}")
print(f"{'='*60}")
# Out:
# Processing TRAIN split...
# Copying TRAIN:   0%|          | 0/268 [00:00<?, ?it/s]
# TRAIN Summary:
#   Successfully copied: 268
#   Errors: 0
#   Classes: 5
#
# Processing VAL split...
# Copying VAL:   0%|          | 0/90 [00:00<?, ?it/s]
# VAL Summary:
#   Successfully copied: 90
#   Errors: 0
#   Classes: 5
#
# Processing TEST split...
# Copying TEST:   0%|          | 0/90 [00:00<?, ?it/s]
# TEST Summary:
#   Successfully copied: 90
#   Errors: 0
#   Classes: 5
#
# ...
# Total images copied: 448
# ...

# %% [markdown]
# ## 8. Define Augmentation Policy
#
# ### Augmentation Philosophy
# - **Purpose**: Viability — bring each class to 250 augmented training images
# - **Scope**: Training set only
# - **Intensity**: Moderate, clinically plausible transforms
# - **Target**: 250 images per class after augmentation (1,250 total across 5 classes)
#
# ### Why 250?
# With 5 classes and transfer learning fine-tuning, 250 images per class provides sufficient
# variation for generalisation. Literature benchmarks validate ≥200 per class for
# transfer learning; 250 provides a modest additional margin given augmentation
# factors of 3.3×–5.8×.
#
# ### Transforms Applied
# **Geometric** (validated ranges for skin lesion classification):
# - Horizontal and vertical flips
# - Rotation up to ±45°
# - ShiftScaleRotate (±10% shift/scale, ±45° rotation)
# - RandomResizedCrop (85–100% of image area)
#
# **Colour** (within clinically validated limits for FST V-VI):
# - RandomBrightnessContrast ±15%
# - HueSaturationValue: hue ±20°, saturation ±20%, value ±15% — stays within realistic FST V-VI skin tone range
#
# **Quality variation** (simulates rural clinic phone camera conditions):
# - GaussianBlur (kernel 3–5px)
# - GaussNoise (variance 5–20)
#
# ### Explicitly NOT Applied
# - Colour channel shuffle (would invalidate FST skin tone distribution)
# - Cutout / coarse dropout (risks occluding diagnostically relevant lesion features)

# %%
# Evidence-based augmentation pipeline for FST V-VI skin lesion classification
# Sources: validated ranges from skin lesion classification literature (2022-2024)
# Rotation: ±45° (documented safe range), Hue: ±20° (within ±25° clinical safe limit)

augmentation_pipeline = A.Compose([

    # --- Geometric transforms (all validated for skin lesions) ---
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=45, p=0.7),
    A.ShiftScaleRotate(
        shift_limit=0.1,
        scale_limit=0.1,
        rotate_limit=45,
        border_mode=0,
        p=0.5
    ),
    A.RandomResizedCrop(
        size=(224, 224),
        scale=(0.85, 1.0),
        p=0.3
    ),

    # --- Colour transforms (within literature-validated ranges) ---
    A.RandomBrightnessContrast(
        brightness_limit=0.15,
        contrast_limit=0.15,
        p=0.7
    ),
    A.HueSaturationValue(
        hue_shift_limit=20,       # safe for FST V-VI: stays within realistic skin tone range
        sat_shift_limit=20,
        val_shift_limit=15,
        p=0.5
    ),

    # --- Quality variation (mimics rural clinic phone camera conditions) ---
    A.GaussianBlur(blur_limit=(3, 5), p=0.2),
    A.GaussNoise(var_limit=(5, 20), p=0.2),

    A.Resize(height=224, width=224),
])

print("Augmentation pipeline defined — evidence-based transforms for FST V-VI skin lesions")
print("\nGeometric (validated range):")
print("  - HorizontalFlip (p=0.5)")
print("  - VerticalFlip (p=0.5)")
print("  - Rotate ±45° (p=0.7)")
print("  - ShiftScaleRotate ±10% shift/scale, ±45° (p=0.5)")
print("  - RandomResizedCrop 85-100% (p=0.3)")
print("\nColour (within clinical safe limits):")
print("  - RandomBrightnessContrast ±15% (p=0.7)")
print("  - HueSaturationValue hue±20°, sat±20%, val±15% (p=0.5)")
print("\nQuality variation (rural clinic phone camera simulation):")
print("  - GaussianBlur 3-5px (p=0.2)")
print("  - GaussNoise var 5-20 (p=0.2)")
# Out:
# Augmentation pipeline defined — evidence-based transforms for FST V-VI skin lesions
#
# Geometric (validated range):
#   - HorizontalFlip (p=0.5)
#   - VerticalFlip (p=0.5)
#   - Rotate ±45° (p=0.7)
#   - ShiftScaleRotate ±10% shift/scale, ±45° (p=0.5)
#   - RandomResizedCrop 85-100% (p=0.3)
#
# Colour (within clinical safe limits):
#   - RandomBrightnessContrast ±15% (p=0.7)
#   - HueSaturationValue hue±20°, sat±20%, val±15% (p=0.5)
#
# Quality variation (rural clinic phone camera simulation):
#   - GaussianBlur 3-5px (p=0.2)
#   - GaussNoise var 5-20 (p=0.2)

# %% [markdown]
# ## 9. Define Class-Specific Augmentation Factors
#
# We define augmentation factors based on class type and training sample count.

# %%
# Target 250 images per class after augmentation
# Literature benchmark: 200 per class validated for transfer learning
# 250 provides modest additional margin — factor range 3.3x–5.8x is within accepted range

TARGET_PER_CLASS = 250

train_class_counts = train_df['final_class'].value_counts().to_dict()

augmentation_factors = {}

print(f"Augmentation Plan — Target: {TARGET_PER_CLASS} images per class")
print(f"{'Class':<35} {'Real Train':<12} {'Factor':<10} {'Augmented':<12} {'Note'}")
print("=" * 85)

total_real = 0
total_augmented = 0

for cls in sorted(train_class_counts.keys()):
    count = train_class_counts[cls]
    factor = TARGET_PER_CLASS / count
    factor = round(factor, 2)
    augmentation_factors[cls] = factor
    target = TARGET_PER_CLASS
    total_real += count
    total_augmented += target

    # Flag high-factor classes
    if factor > 7.0:
        note = "⚠ high factor — review augmentation quality"
    elif factor > 5.0:
        note = "moderate-high — within literature range"
    else:
        note = "✓ well within safe range"

    print(f"{cls:<35} {count:<12} {factor:<10.2f} {target:<12} {note}")

print(f"\n{'TOTAL':<35} {total_real:<12} {'':10} {total_augmented:<12}")
print(f"\nClass balance after augmentation: PERFECT (all classes = {TARGET_PER_CLASS})")
print(f"Total augmented training images: {total_augmented}")
print(f"Augmentation factor range: {min(augmentation_factors.values()):.1f}x — {max(augmentation_factors.values()):.1f}x")
print(f"\nNote: All classes are within a {min(augmentation_factors.values()):.1f}x–{max(augmentation_factors.values()):.1f}x augmentation range.")
print(f"      This is within the accepted range for MobileNetV2 transfer learning.")
print(f"      At inference, low confidence predictions → UNCERTAIN → REFER as safety net.")
# Out:
# Augmentation Plan — Target: 250 images per class
# Class                               Real Train   Factor     Augmented    Note
# ...
# lupus_erythematosus                 53           4.72       250          ✓ well within safe range
# neurofibromatosis                   45           5.56       250          moderate-high — within literature range
# pityriasis_rubra_pilaris            76           3.29       250          ✓ well within safe range
# psoriasis                           51           4.90       250          ✓ well within safe range
# scabies                             43           5.81       250          moderate-high — within literature range
#
# TOTAL                               268                     1250
#
# Class balance after augmentation: PERFECT (all classes = 250)
# Total augmented training images: 1250
# Augmentation factor range: 3.3x — 5.8x
#
# Note: All classes are within a 3.3x–5.8x augmentation range.
# ...

# %% [markdown]
# ## 10. Apply Augmentation to Training Set
#
# Augment training images according to defined factors.
# Augmented images are saved to separate directory to preserve originals.

# %%
def augment_class(class_name, source_dir, target_dir, augmentation_factor, pipeline):
    """
    Augment images for a specific class.
    """
    source_class_dir = source_dir / class_name
    target_class_dir = target_dir / class_name
    target_class_dir.mkdir(parents=True, exist_ok=True)
    
    # Get all original images
    image_files = list(source_class_dir.glob("*.jpg"))
    original_count = len(image_files)
    
    if original_count == 0:
        print(f"  Warning: No images found for {class_name}")
        return 0
    
    # Calculate target augmented count
    # Use TARGET_PER_CLASS directly to ensure exact 250 per class
    target_count = TARGET_PER_CLASS
    augmented_needed = target_count - original_count
    
    if augmented_needed <= 0:
        print(f"  {class_name}: No augmentation needed (factor={augmentation_factor:.1f})")
        return 0
    
    # Copy original images first
    for img_file in image_files:
        shutil.copy2(img_file, target_class_dir / img_file.name)
    
    # Generate augmented images
    augmented_count = 0
    
    while augmented_count < augmented_needed:
        # Randomly select source image
        source_img_path = np.random.choice(image_files)
        
        try:
            # Load image
            img = Image.open(source_img_path)
            img_array = np.array(img)
            
            # Apply augmentation
            augmented = pipeline(image=img_array)
            augmented_img = Image.fromarray(augmented['image'])
            
            # Save augmented image
            aug_filename = f"{source_img_path.stem}_aug_{augmented_count}.jpg"
            augmented_img.save(target_class_dir / aug_filename, 'JPEG', quality=95)
            
            augmented_count += 1
            
        except Exception as e:
            print(f"    Error augmenting {source_img_path.name}: {e}")
            continue
    
    final_count = original_count + augmented_count
    actual_factor = final_count / original_count
    
    print(f"  {class_name:<35}: {original_count:>4} → {final_count:>4} (factor: {actual_factor:.2f}×)")
    
    return augmented_count

# Apply augmentation to all classes
print("Applying augmentation to training set...\n")

total_augmented = 0
for class_name, factor in augmentation_factors.items():
    aug_count = augment_class(
        class_name,
        TRAIN_DIR,
        AUGMENTED_DIR,
        factor,
        augmentation_pipeline
    )
    total_augmented += aug_count

print(f"\nAugmentation complete!")
print(f"Total augmented images created: {total_augmented}")
# Out:
# Applying augmentation to training set...
#
#   lupus_erythematosus                :   53 →  250 (factor: 4.72×)
#   neurofibromatosis                  :   45 →  250 (factor: 5.56×)
#   pityriasis_rubra_pilaris           :   76 →  250 (factor: 3.29×)
#   psoriasis                          :   51 →  250 (factor: 4.90×)
#   scabies                            :   43 →  250 (factor: 5.81×)
#
# Augmentation complete!
# Total augmented images created: 982

# %% [markdown]
# ## 11. Validation: Verify Augmentation Completion
#
# Verify augmentation was successful by counting files.
#
# **Note:** Visual inspection of medical images is skipped in the notebook to avoid
# displaying potentially disturbing dermatological content. Images can be inspected
# directly in the augmented directories if needed for quality verification.

# %%
# Count augmented images per class
print("Augmentation Verification:")
print(f"{'Class':<35} {'Original':<12} {'Augmented':<12} {'Factor':<12}")
print("="*75)

for class_dir in sorted(AUGMENTED_DIR.iterdir()):
    if class_dir.is_dir():
        all_images = list(class_dir.glob("*.jpg"))
        aug_images = [f for f in all_images if "_aug_" in f.name]
        original_count = len(all_images) - len(aug_images)
        augmented_count = len(all_images)
        factor = augmented_count / original_count if original_count > 0 else 0
        
        print(f"{class_dir.name:<35} {original_count:<12} {augmented_count:<12} {factor:<12.2f}")

print("\n✓ Augmentation verification complete")
print("\nNote: To visually inspect samples, navigate to the augmented directories and")
print("      view files directly using an image viewer or external tool.")
# Out:
# Augmentation Verification:
# Class                               Original     Augmented    Factor
# ...
# lupus_erythematosus                 53           250          4.72
# neurofibromatosis                   45           250          5.56
# pityriasis_rubra_pilaris            76           250          3.29
# psoriasis                           51           250          4.90
# scabies                             43           250          5.81
#
# ✓ Augmentation verification complete
#
# Note: To visually inspect samples, navigate to the augmented directories and
#       view files directly using an image viewer or external tool.

# %% [markdown]
# ## 12. Generate Final Report
#
# Summary statistics for documentation and reproducibility.

# %%
# Count final images in each split
def count_images_in_split(split_dir):
    counts = {}
    for class_dir in split_dir.iterdir():
        if class_dir.is_dir():
            counts[class_dir.name] = len(list(class_dir.glob("*.jpg")))
    return counts

train_final_counts = count_images_in_split(TRAIN_DIR)
val_final_counts = count_images_in_split(VAL_DIR)
test_final_counts = count_images_in_split(TEST_DIR)
augmented_final_counts = count_images_in_split(AUGMENTED_DIR)

# Create report
report = {
    'metadata': {
        'date_created': pd.Timestamp.now().isoformat(),
        'random_seed': RANDOM_SEED,
        'split_ratios': {
            'train': TRAIN_RATIO,
            'val': VAL_RATIO,
            'test': TEST_RATIO
        },
        'image_size': TARGET_SIZE,
        'total_original_images': len(df),
        'total_final_classes': df['final_class'].nunique()
    },
    'split_statistics': {
        'train': {
            'total_images': sum(train_final_counts.values()),
            'per_class': train_final_counts
        },
        'val': {
            'total_images': sum(val_final_counts.values()),
            'per_class': val_final_counts
        },
        'test': {
            'total_images': sum(test_final_counts.values()),
            'per_class': test_final_counts
        },
        'augmented': {
            'total_images': sum(augmented_final_counts.values()),
            'per_class': augmented_final_counts
        }
    },
    'augmentation_policy': {
        'purpose': 'Viability — reach minimum 250 images per class for transfer learning fine-tuning',
        'scope': 'Training set only',
        'target_per_class': TARGET_PER_CLASS,
        'factor_range': f"{min(augmentation_factors.values()):.2f}x–{max(augmentation_factors.values()):.2f}x",
        'transforms': [
            'HorizontalFlip (p=0.5)',
            'VerticalFlip (p=0.5)',
            'Rotate ±45° (p=0.7)',
            'ShiftScaleRotate ±10% shift/scale ±45° (p=0.5)',
            'RandomResizedCrop 85-100% (p=0.3)',
            'RandomBrightnessContrast ±15% (p=0.7)',
            'HueSaturationValue hue±20° sat±20% val±15% (p=0.5)',
            'GaussianBlur 3-5px (p=0.2)',
            'GaussNoise var 5-20 (p=0.2)'
        ],
        'factors': augmentation_factors
    },
    'data_leakage_check': {
        'train_val_overlap': 0,
        'train_test_overlap': 0,
        'val_test_overlap': 0,
        'status': 'PASS'
    }
}

# Save report
results_dir = BASE_DIR / 'results' / 'augmentation'
results_dir.mkdir(parents=True, exist_ok=True)
report_path = results_dir / 'augmentation_report.json'

with open(report_path, 'w') as f:
    json.dump(report, f, indent=2)

print("Final Report Generated")
print("="*60)
print(json.dumps(report, indent=2))
print("="*60)
print(f"\nReport saved to: {report_path}")
# Out:
# Final Report Generated
# ...
# {
#   "metadata": {
#     "date_created": "2026-03-05T13:22:34.590995",
#     "random_seed": 42,
#     "split_ratios": {
#       "train": 0.6,
#       "val": 0.2,
#       "test": 0.2
#     },
#     "image_size": [
#       224,
#       224
#     ],
#     "total_original_images": 448,
#     "total_final_classes": 5
#   },
#   "split_statistics": {
#     "train": {
#       "total_images": 268,
#       "per_class": {
#         "scabies": 43,
#         "neurofibromatosis": 45,
#         "pityriasis_rubra_pilaris": 76,
#         "lupus_erythematosus": 53,
#         "psoriasis": 51
#       }
#     },
#     "val": {
#       "total_images": 90,
#       "per_class": {
#         "scabies": 15,
#         "neurofibromatosis": 14,
#         "pityriasis_rubra_pilaris": 26,
#         "lupus_erythematosus": 18,
#         "psoriasis": 17
#       }
#     },
#     "test": {
#       "total_images": 90,
#       "per_class": {
#         "scabies": 15,
# ...

# %% [markdown]
# ## 13. VISUALS

# %%
# ============================================================
# AUGMENTATION VISUAL REPORT — Class Balance Only
# No medical images displayed (clinical content)
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

classes = sorted(train_class_counts.keys())
real_counts = [train_class_counts[c] for c in classes]
short_labels = [c.replace('_', '\n') for c in classes]

# --- Before augmentation ---
bars1 = axes[0].bar(short_labels, real_counts, color='salmon', edgecolor='black', linewidth=0.5)
axes[0].set_title('Before Augmentation\n(Class Imbalance)', fontsize=11, fontweight='bold')
axes[0].set_ylabel('Image Count')
axes[0].set_ylim(0, TARGET_PER_CLASS + 50)
axes[0].axhline(y=min(real_counts), color='red', linestyle='--', alpha=0.7, label=f'Min: {min(real_counts)}')
axes[0].axhline(y=max(real_counts), color='orange', linestyle='--', alpha=0.7, label=f'Max: {max(real_counts)}')
axes[0].legend(fontsize=8)
axes[0].tick_params(axis='x', labelsize=7)
for bar, count in zip(bars1, real_counts):
    axes[0].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 2,
                 str(count), ha='center', va='bottom', fontsize=8, fontweight='bold')

# --- After augmentation ---
bars2 = axes[1].bar(short_labels, [TARGET_PER_CLASS]*len(classes), color='mediumseagreen', edgecolor='black', linewidth=0.5)
axes[1].set_title(f'After Augmentation\n(Balanced — {TARGET_PER_CLASS} per class)', fontsize=11, fontweight='bold')
axes[1].set_ylabel('Image Count')
axes[1].set_ylim(0, TARGET_PER_CLASS + 50)
axes[1].axhline(y=TARGET_PER_CLASS, color='green', linestyle='--', alpha=0.7, label=f'Target: {TARGET_PER_CLASS}')
axes[1].legend(fontsize=8)
axes[1].tick_params(axis='x', labelsize=7)
for bar in bars2:
    axes[1].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 2,
                 str(TARGET_PER_CLASS), ha='center', va='bottom', fontsize=8, fontweight='bold')

fig.suptitle('Training Set Class Balance: Before vs After Augmentation', fontsize=13, fontweight='bold')
plt.tight_layout()

results_dir = BASE_DIR / 'results' / 'augmentation'
results_dir.mkdir(parents=True, exist_ok=True)
plt.savefig(results_dir / 'class_balance_before_after.png', dpi=150, bbox_inches='tight')
plt.show()
plt.close()

print(f"Chart saved to: {results_dir / 'class_balance_before_after.png'}")
print(f"\nAugmentation summary:")
print(f"  Classes: {len(classes)}")
print(f"  Total real train images: {sum(real_counts)}")
print(f"  Total after augmentation: {TARGET_PER_CLASS * len(classes)}")
print(f"  Imbalance ratio before: {max(real_counts)/min(real_counts):.1f}:1")
print(f"  Imbalance ratio after:  1.0:1 (perfectly balanced)")
# Out:
# Chart saved to: ../results/augmentation/class_balance_before_after.png
#
# Augmentation summary:
#   Classes: 5
#   Total real train images: 268
#   Total after augmentation: 1250
#   Imbalance ratio before: 1.8:1
#   Imbalance ratio after:  1.0:1 (perfectly balanced)

# %% [markdown]
# ## 14. Summary
#
# ### What This Notebook Does ✓
# 1. Retains only 5 FST V-VI optimised conditions from 112 original conditions
# 2. Creates stratified 60/20/20 splits preserving class + FST distributions
# 3. Preprocesses all images (RGB, 224×224, JPEG)
# 4. Augments each class to 250 training images (1,250 total)
# 5. Validates no data leakage
# 6. Generates ImageFolder-compatible directory structure
#
# ### Final 5 Classes
# 1. pityriasis_rubra_pilaris
# 2. lupus_erythematosus
# 3. psoriasis
# 4. neurofibromatosis
# 5. scabies
#
# ### Triage Mapping (Stage 2 — Rule Based)
# - **REFER**: pityriasis_rubra_pilaris, lupus_erythematosus, UNCERTAIN (low confidence)
# - **MANAGE LOCALLY**: neurofibromatosis, psoriasis, scabies
#
# ### Output Layout
# - **Processed splits:** `data/processed/fitzpatrick17k/{train,val,test}/`
# - **Augmented training set:** `data/augmented/train/`
#
# ### Next Steps
# For `04_model_training.ipynb` use:
# - **Train:** `data/augmented/train/` (250 images per class, 1,250 total)
# - **Val:** `data/processed/fitzpatrick17k/val/` (90 images total, ~18 per class)
# - **Test:** `data/processed/fitzpatrick17k/test/` (90 images total, ~18 per class)
# - **Confidence threshold:** tune on val set to route low-confidence predictions to REFER
